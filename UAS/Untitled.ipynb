# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
#202331175_Rizalwirap

# %%
image = cv.imread("Rizal Close.jpeg")
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#202331175_Rizalwirap

# %%
fig, axs = plt.subplots(1,2, figsize = (10,10))
ax = axs.ravel()

axs[0].imshow(image_rgb, cmap = "gray")
axs[0].set_title("Gambar RGB Original")
# Out:
# Text(0.5, 1.0, 'Gambar RGB Original')

# %%
image.shape
#202331175_Rizalwirap
# Out:
# (4160, 3120, 3)

# %%
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray, 75, 150)
#202331175_Rizalwirap

# %%
cv.imshow("Gambar Parkir", edges)
cv.waitKey(0)
cv.destroyAllWindows()
#202331175_Rizalwirap

# %%
fig, axs = plt.subplots(1,3, figsize = (10,10))
ax = axs.ravel()

axs[0].imshow(image, cmap = "gray")
axs[0].set_title("Parkir 3 channel RGB")

axs[1].imshow(gray, cmap = "gray")
axs[1].set_title("Parkir convert Grayscale")

axs[2].imshow(edges, cmap = "gray")
axs[2].set_title("Parkir tepi Canny")
#202331175_Rizalwirap

# %%
fig, axs = plt.subplots(1,2, figsize = (10,10))
ax = axs.ravel()

axs[0].imshow(edges, cmap = "gray")
axs[0].set_title("Deteksi Tepi")
